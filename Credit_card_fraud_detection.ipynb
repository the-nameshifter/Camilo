# %% [markdown]
# <a href="https://colab.research.google.com/github/the-nameshifter/Camilo/blob/Machine-Learning/Credit_card_fraud_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problem statement
#
# - Crediit card companies need to have the ability to recognize fraudulent credit card transactions so that customers are not charged for items that they did not purchase.
# - Datasets contains transactions made by credit cards in September 2013 by european cradholders.
# - Output: 1 in case of fraud and 0 otherwise.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
credit_card_DF = pd.read_csv('/content/creditcard.csv')

# %%
credit_card_DF
# Out:
#             Time         V1         V2  ...       V28  Amount  Class
# 0            0.0  -1.359807  -0.072781  ... -0.021053  149.62      0
# 1            0.0   1.191857   0.266151  ...  0.014724    2.69      0
# 2            1.0  -1.358354  -1.340163  ... -0.059752  378.66      0
# 3            1.0  -0.966272  -0.185226  ...  0.061458  123.50      0
# 4            2.0  -1.158233   0.877737  ...  0.215153   69.99      0
# ...          ...        ...        ...  ...       ...     ...    ...
# 284802  172786.0 -11.881118  10.071785  ...  0.823731    0.77      0
# 284803  172787.0  -0.732789  -0.055080  ... -0.053527   24.79      0
# 284804  172788.0   1.919565  -0.301254  ... -0.026561   67.88      0
# 284805  172788.0  -0.240440   0.530483  ...  0.104533   10.00      0
# 284806  172792.0  -0.533413  -0.189733  ...  0.013649  217.00      0
#
# [284807 rows x 31 columns]

# %%
credit_card_DF.describe()
# Out:
#                 Time            V1  ...         Amount          Class
# count  284807.000000  2.848070e+05  ...  284807.000000  284807.000000
# mean    94813.859575  3.919560e-15  ...      88.349619       0.001727
# std     47488.145955  1.958696e+00  ...     250.120109       0.041527
# min         0.000000 -5.640751e+01  ...       0.000000       0.000000
# 25%     54201.500000 -9.203734e-01  ...       5.600000       0.000000
# 50%     84692.000000  1.810880e-02  ...      22.000000       0.000000
# 75%    139320.500000  1.315642e+00  ...      77.165000       0.000000
# max    172792.000000  2.454930e+00  ...   25691.160000       1.000000
#
# [8 rows x 31 columns]

# %%
credit_card_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# # Visualization

# %%
non_fraud  = credit_card_DF[ credit_card_DF['Class']==0]

# %%
fraud  = credit_card_DF[ credit_card_DF['Class']==1]

# %%
fraud
# Out:
#             Time        V1        V2  ...       V28  Amount  Class
# 541        406.0 -2.312227  1.951992  ... -0.143276    0.00      1
# 623        472.0 -3.043541 -3.157307  ...  0.035764  529.00      1
# 4920      4462.0 -2.303350  1.759247  ... -0.153029  239.93      1
# 6108      6986.0 -4.397974  1.358367  ...  0.849573   59.00      1
# 6329      7519.0  1.234235  3.019740  ...  0.146793    1.00      1
# ...          ...       ...       ...  ...       ...     ...    ...
# 279863  169142.0 -1.927883  1.125653  ...  0.147968  390.00      1
# 280143  169347.0  1.378559  1.289381  ...  0.186637    0.76      1
# 280149  169351.0 -0.676143  1.126366  ...  0.194361   77.89      1
# 281144  169966.0 -3.113832  0.585864  ... -0.253700  245.00      1
# 281674  170348.0  1.991976  0.158476  ... -0.015309   42.53      1
#
# [492 rows x 31 columns]

# %%
non_fraud
# Out:
#             Time         V1         V2  ...       V28  Amount  Class
# 0            0.0  -1.359807  -0.072781  ... -0.021053  149.62      0
# 1            0.0   1.191857   0.266151  ...  0.014724    2.69      0
# 2            1.0  -1.358354  -1.340163  ... -0.059752  378.66      0
# 3            1.0  -0.966272  -0.185226  ...  0.061458  123.50      0
# 4            2.0  -1.158233   0.877737  ...  0.215153   69.99      0
# ...          ...        ...        ...  ...       ...     ...    ...
# 284802  172786.0 -11.881118  10.071785  ...  0.823731    0.77      0
# 284803  172787.0  -0.732789  -0.055080  ... -0.053527   24.79      0
# 284804  172788.0   1.919565  -0.301254  ... -0.026561   67.88      0
# 284805  172788.0  -0.240440   0.530483  ...  0.104533   10.00      0
# 284806  172792.0  -0.533413  -0.189733  ...  0.013649  217.00      0
#
# [284315 rows x 31 columns]

# %%
print('Fraud transactions % = ', (len(fraud)/len(credit_card_DF) * 100, '%'))
# Out:
# Fraud transactions % =  (0.1727485630620034, '%')

# %%
sns.countplot(credit_card_DF['Class'], label = 'Count')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
Correlations = credit_card_DF.corr()
f, ax = plt.subplots(figsize = (30, 10))
sns.heatmap(Correlations, annot = True)

# %%
column_headers = credit_card_DF.columns.values

# %%
column_headers
# Out:
# array(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9',
#        'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18',
#        'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27',
#        'V28', 'Amount', 'Class', 'Amount_Norm'], dtype=object)

# %% [markdown]
# ## Feature scaling to normalize the "Amount" column

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
credit_card_DF['Amount']
credit_card_DF['Amount_Norm'] = sc.fit_transform(credit_card_DF['Amount'].values.reshape(-1,1))

# %%
credit_card_DF
# Out:
#             Time         V1         V2  ...  Amount  Class  Amount_Norm
# 0            0.0  -1.359807  -0.072781  ...  149.62      0     0.244964
# 1            0.0   1.191857   0.266151  ...    2.69      0    -0.342475
# 2            1.0  -1.358354  -1.340163  ...  378.66      0     1.160686
# 3            1.0  -0.966272  -0.185226  ...  123.50      0     0.140534
# 4            2.0  -1.158233   0.877737  ...   69.99      0    -0.073403
# ...          ...        ...        ...  ...     ...    ...          ...
# 284802  172786.0 -11.881118  10.071785  ...    0.77      0    -0.350151
# 284803  172787.0  -0.732789  -0.055080  ...   24.79      0    -0.254117
# 284804  172788.0   1.919565  -0.301254  ...   67.88      0    -0.081839
# 284805  172788.0  -0.240440   0.530483  ...   10.00      0    -0.313249
# 284806  172792.0  -0.533413  -0.189733  ...  217.00      0     0.514355
#
# [284807 rows x 32 columns]

# %% [markdown]
# # Let's drop the target Label columns

# %%
credit_card_DF = credit_card_DF.drop(['Amount'], axis=1)

# %%
credit_card_DF
# Out:
#             Time         V1         V2  ...       V28  Class  Amount_Norm
# 0            0.0  -1.359807  -0.072781  ... -0.021053      0     0.244964
# 1            0.0   1.191857   0.266151  ...  0.014724      0    -0.342475
# 2            1.0  -1.358354  -1.340163  ... -0.059752      0     1.160686
# 3            1.0  -0.966272  -0.185226  ...  0.061458      0     0.140534
# 4            2.0  -1.158233   0.877737  ...  0.215153      0    -0.073403
# ...          ...        ...        ...  ...       ...    ...          ...
# 284802  172786.0 -11.881118  10.071785  ...  0.823731      0    -0.350151
# 284803  172787.0  -0.732789  -0.055080  ... -0.053527      0    -0.254117
# 284804  172788.0   1.919565  -0.301254  ... -0.026561      0    -0.081839
# 284805  172788.0  -0.240440   0.530483  ...  0.104533      0    -0.313249
# 284806  172792.0  -0.533413  -0.189733  ...  0.013649      0     0.514355
#
# [284807 rows x 31 columns]

# %% [markdown]
# # Create testing and training dataset

# %%
X =  credit_card_DF.drop(['Class'], axis = 1)
y = credit_card_DF['Class']

# %%
X
# Out:
#             Time         V1         V2  ...       V27       V28  Amount_Norm
# 0            0.0  -1.359807  -0.072781  ...  0.133558 -0.021053     0.244964
# 1            0.0   1.191857   0.266151  ... -0.008983  0.014724    -0.342475
# 2            1.0  -1.358354  -1.340163  ... -0.055353 -0.059752     1.160686
# 3            1.0  -0.966272  -0.185226  ...  0.062723  0.061458     0.140534
# 4            2.0  -1.158233   0.877737  ...  0.219422  0.215153    -0.073403
# ...          ...        ...        ...  ...       ...       ...          ...
# 284802  172786.0 -11.881118  10.071785  ...  0.943651  0.823731    -0.350151
# 284803  172787.0  -0.732789  -0.055080  ...  0.068472 -0.053527    -0.254117
# 284804  172788.0   1.919565  -0.301254  ...  0.004455 -0.026561    -0.081839
# 284805  172788.0  -0.240440   0.530483  ...  0.108821  0.104533    -0.313249
# 284806  172792.0  -0.533413  -0.189733  ... -0.002415  0.013649     0.514355
#
# [284807 rows x 30 columns]

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %% [markdown]
# # Training the model

# %%
X_train.shape
# Out:
# (227845, 30)

# %%
X_test.shape
# Out:
# (56962, 30)

# %%
y_train.shape
# Out:
# (227845,)

# %%
y_test.shape
# Out:
# (56962,)

# %% [markdown]
# # We use Gaussian Naives Bayes

# %%
from sklearn.naive_bayes import GaussianNB
classifier_GNB = GaussianNB()
classifier_GNB.fit(X_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# # Evaluating the model

# %%
# Predict the training set results
from sklearn.metrics import confusion_matrix, classification_report

y_predict_train = classifier_GNB.predict(X_train)
cm = confusion_matrix(y_train, y_predict_train) 
sns.heatmap(cm, annot = True)

# %%
# predict the Test set results

y_predict_test = classifier_GNB.predict(X_test)
cm = confusion_matrix(y_test, y_predict_test) 
sns.heatmap(cm, annot = True)

# %%
print(classification_report(y_test, y_predict_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     56861
#            1       0.15      0.62      0.24       101
#
#     accuracy                           0.99     56962
#    macro avg       0.58      0.81      0.62     56962
# weighted avg       1.00      0.99      1.00     56962

# %% [markdown]
# # Improving the model

# %%
# Drop similar features columns
X = credit_card_DF.drop(['Time', 'V8', 'V15', 'V20', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', "Class"], axis= 1)

# %%
X
# Out:
#                V1         V2        V3  ...       V19       V21  Amount_Norm
# 0       -1.359807  -0.072781  2.536347  ...  0.403993 -0.018307     0.244964
# 1        1.191857   0.266151  0.166480  ... -0.145783 -0.225775    -0.342475
# 2       -1.358354  -1.340163  1.773209  ... -2.261857  0.247998     1.160686
# 3       -0.966272  -0.185226  1.792993  ... -1.232622 -0.108300     0.140534
# 4       -1.158233   0.877737  1.548718  ...  0.803487 -0.009431    -0.073403
# ...           ...        ...       ...  ...       ...       ...          ...
# 284802 -11.881118  10.071785 -9.834783  ... -0.682920  0.213454    -0.350151
# 284803  -0.732789  -0.055080  2.035030  ... -1.545556  0.214205    -0.254117
# 284804   1.919565  -0.301254 -3.249640  ... -0.577252  0.232045    -0.081839
# 284805  -0.240440   0.530483  0.702510  ...  2.897849  0.265245    -0.313249
# 284806  -0.533413  -0.189733  0.703337  ... -0.256117  0.261057     0.514355
#
# [284807 rows x 19 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
from sklearn.naive_bayes import GaussianNB
classifier_GNB = GaussianNB()
classifier_GNB.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_predict_train = classifier_GNB.predict(X_train)
cm = confusion_matrix(y_train, y_predict_train) 
sns.heatmap(cm, annot = True)

# %%
# predict the Test set results

y_predict_test = classifier_GNB.predict(X_test)
cm = confusion_matrix(y_test, y_predict_test) 
sns.heatmap(cm, annot = True)

# %%
print(classification_report(y_test, y_predict_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56863
#            1       0.09      0.83      0.16        99
#
#     accuracy                           0.98     56962
#    macro avg       0.54      0.91      0.57     56962
# weighted avg       1.00      0.98      0.99     56962

# %%
print("Number of fraud points in the testing dataset = ", sum(y_test))
# Out:
# Number of fraud points in the testing dataset =  99
